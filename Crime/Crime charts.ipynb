# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sts
import numpy as np

# %%
atlantic_df = pd.read_csv('Atlantic_Crime.csv')

atlantic_df.head()
# Out:
#    Year  Murder  Rape  Robbery  Assault  Burglary  Larceny  Auto Theft  Total
# 0  2010      22    54      716      767      2099     7637         334  11629
# 1  2011      22    57      603      712      2144     6931         332  10801
# 2  2012      29    74      471      669      1814     6339         292   9688
# 3  2013       8    38      521      657      1731     6190         230   9375
# 4  2014      18    55      489      502      1650     6280         206   9200

# %%
atlantic_chart = atlantic_df[['Year', 'Total']]
atlantic_chart = atlantic_chart.set_index("Year")
atlantic_chart
# Out:
#       Total
# Year
# 2010  11629
# 2011  10801
# 2012   9688
# 2013   9375
# 2014   9200
# 2015   8899
# 2016   7870
# 2017   7816
# 2018   6402
# 2019   6986
# 2020   3314

# %%
atlantic_chart.plot(kind="bar", color='green')

plt.title("Total crime by year, Atlantic County NJ")
plt.xlabel("Year")
plt.ylabel("Number of Crimes")
plt.savefig("Total_Crime_Atlantic.png")
plt.show()

# %%
atlantic_df = atlantic_df.set_index("Year")
del atlantic_df['Total']
atlantic_line = atlantic_df.transpose()

atlantic_line
# Out:
# Year        2010  2011  2012  2013  2014  2015  2016  2017  2018  2019  2020
# Murder        22    22    29     8    18    20    21    21    16    13     7
# Rape          54    57    74    38    55    57    65    54    46    49    38
# Robbery      716   603   471   521   489   515   399   345   231   272    98
# Assault      767   712   669   657   502   547   499   428   391   338   255
# Burglary    2099  2144  1814  1731  1650  1444  1337  1230   865   857   478
# Larceny     7637  6931  6339  6190  6280  6090  5294  5460  4657  5174  2280
# Auto Theft   334   332   292   230   206   226   255   278   196   283   158

# %%
atlantic_line.loc['Murder', "2010":"2020"].plot(label="Murder")
atlantic_line.loc['Rape', "2010":"2020"].plot(label="Rape")
atlantic_line.loc['Robbery', "2010":"2020"].plot(label="Robbery")
atlantic_line.loc['Assault', "2010":"2020"].plot(label="Assault")
atlantic_line.loc['Burglary', "2010":"2020"].plot(label="Burglary")
atlantic_line.loc['Larceny', "2010":"2020"].plot(label="Larceny")
atlantic_line.loc['Auto Theft', "2010":"2020"].plot(label="Auto Theft")
plt.legend()
plt.title("Crime by type over time, Atlantic County NJ")
plt.xlabel("Year")
plt.ylabel("Number of Crimes")
plt.savefig("Crime_Type_Atlantic.png")
plt.show()

# %%
harris_df = pd.read_csv('Harris_Crime.csv')

harris_df.head()
# Out:
#    Year  Murder  Rape  Robbery  Assault  Burglary  Larceny  Auto Theft   Total
# 0  2015     404  1681    14293    16602     32374   108379       21796  195529
# 1  2016     409  2020    13656    18729     30224   112162       20491  197691
# 2  2017     376  2187    13288    20660     27352   109057       18503  191423
# 3  2018     379  2233    11559    21042     25752   105086       19555  185606
# 4  2019     372  2101    11396    18709     24082   101081       19114  176855

# %%
harris_chart = harris_df[['Year', 'Total']]
harris_chart = harris_chart.set_index("Year")
harris_chart
# Out:
#        Total
# Year
# 2015  195529
# 2016  197691
# 2017  191423
# 2018  185606
# 2019  176855

# %%
harris_chart.plot(kind="bar", color="green", figsize =(8,5))

plt.title("Total crime by year, Harris County TX")
plt.xlabel("Year")
plt.ylabel("Number of Crimes")
plt.savefig("Total_Crime_Harris.png")
plt.show()

# %%
harris_df = harris_df.set_index("Year")
del harris_df['Total']
harris_line = harris_df.transpose()

harris_line
# Out:
# Year          2015    2016    2017    2018    2019
# Murder         404     409     376     379     372
# Rape          1681    2020    2187    2233    2101
# Robbery      14293   13656   13288   11559   11396
# Assault      16602   18729   20660   21042   18709
# Burglary     32374   30224   27352   25752   24082
# Larceny     108379  112162  109057  105086  101081
# Auto Theft   21796   20491   18503   19555   19114

# %%
harris_line.loc['Murder', "2015":"2019"].plot(label="Murder")
harris_line.loc['Rape', "2015":"2019"].plot(label="Rape")
harris_line.loc['Robbery', "2015":"2019"].plot(label="Robbery")
harris_line.loc['Assault', "2015":"2019"].plot(label="Assault")
harris_line.loc['Burglary', "2015":"2019"].plot(label="Burglary")
harris_line.loc['Larceny', "2015":"2019"].plot(label="Larceny")
harris_line.loc['Auto Theft', "2015":"2019"].plot(label="Auto Theft")
plt.xlim(2015, 2019)
x_ticks = np.arange(2015, 2020, 1)
plt.xticks(x_ticks)
plt.xlim(2014.75, 2019.25)
plt.legend()
plt.title("Crime by type over time, Harris County TX")
plt.xlabel("Year")
plt.ylabel("Number of Crimes")
plt.tight_layout()
#plt.figure(figsize=(1,1))
plt.savefig("Crime_Type_Harris.png")
plt.show()
